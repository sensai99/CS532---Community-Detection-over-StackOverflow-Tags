# %%
from google.cloud import storage

# Set up the client
client = storage.Client()

# List all buckets in the project
buckets = client.list_buckets()

# Print the bucket names
print("Buckets in your project:")
for bucket in buckets:
    print(bucket.name)
# Out:
# Buckets in your project:
# 532-dataset
# dataproc-staging-us-central1-891043604939-a9angly8
# dataproc-temp-us-central1-891043604939-otx0so7s

# %%
from google.cloud import storage

# Set up the client
client = storage.Client()

# Define the bucket name
bucket_name = "532-dataset"

# Get the bucket
bucket = client.get_bucket(bucket_name)

blob = bucket.blob("vectors.npz")  # Replace with the exact file name
blob.download_to_filename("./vectors.npz")  # Download the file to the current directory
print("File downloaded successfully!")
# Out:
# File downloaded successfully!
